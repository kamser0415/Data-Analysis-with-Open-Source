# %% [markdown]
# <a href="https://colab.research.google.com/github/kamser0415/Data-Analysis-with-Open-Source/blob/main/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_6%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오픈소스 기반 데이터 분석 6강 - 데이터 전처리 1

# %% [markdown]
# ### 6-1 데이터 훑어보기

# %%
import pandas as pd
import numpy as np

data = {
    'name': ['김민수', '이지영', '박준호', '최서연', '정도윤'],
    'age': [25, 30, 28, 22, 35],
    'city': ['서울', '부산', '인천', '서울', '대전'],
    'score': [90, 85, 95, 80, np.nan]
}
df = pd.DataFrame(data)

# 데이터 측정

# 모든 데이터 타입 측정

# 수치형 데이터 측정

# 범주형 데이터 측정

# 특정 열 분석

# %% [markdown]
# # 새 섹션

# %% [markdown]
# ### 6-2 DataFrame 열 선택 및 **조작**

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}
df = pd.DataFrame(data)

# 특정 열 선택

# DataFrame 열순서 변경

# DataFrame 열이름 변경

# %% [markdown]
# ### 6-3 DataFrame 행 선택

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

#DataFrame 인덱스 지정

#DataFrame 행 선택

#DataFrame 위치 기반 행 선택

#DataFrame 조건 기반 선택

# %% [markdown]
# ### 6-4 DataFrame 정렬

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

#DataFrame 인덱스 지정

#DataFrame 단일 열 오름차순, 내림차순 정렬

#DataFrame 복수 열 오름차순, 내림차순 정렬

#DataFrame 인덱스 기분 오른차순, 내림차순 정렬

# %% [markdown]
# ## 6-5 실습 시나리오 - Kaggle을 활용한 데이터 수집 및 측정

# %% [markdown]
# - Kaggle([https://www.kaggle.com](https://www.kaggle.com)) 회원 가입
# - Kaggle 접근 토큰 생성(API 키)

# %% [markdown]
# ### Kaggle API 키 업로드

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4420d2af-b3eb-447c-ac33-93a517daa067" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4420d2af-b3eb-447c-ac33-93a517daa067">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Kaggle API 키 사용을 위한 Colab 환경 설정

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# ### Kaggle 데이터셋 다운로드

# %%
# !kaggle competitions download -c store-sales-time-series-forecasting

# !unzip store-sales-time-series-forecasting.zip
# Out:
# ...
#   0% 0.00/21.4M [00:00<?, ?B/s]
# 100% 21.4M/21.4M [00:00<00:00, 583MB/s]
# Archive:  store-sales-time-series-forecasting.zip
#   inflating: holidays_events.csv
#   inflating: oil.csv
#   inflating: sample_submission.csv
#   inflating: stores.csv
#   inflating: test.csv
#   inflating: train.csv
#   inflating: transactions.csv

# %% [markdown]
# ### Kaggle 데이터셋 DataFrame 로드 및 살펴보기

# %%
import pandas as pd

# Grocery Sales 데이터 DataFrame 로드
train = pd.read_csv('train.csv')
stores = pd.read_csv('stores.csv')
transactions = pd.read_csv('transactions.csv')
oil = pd.read_csv('oil.csv')
holidays_events = pd.read_csv('holidays_events.csv')

# 판매 데이터 살펴보기
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000888 entries, 0 to 3000887
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   date         object
#  2   store_nbr    int64
#  3   family       object
#  4   sales        float64
#  5   onpromotion  int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 137.4+ MB

# %% [markdown]
# ### Kaggle 데이터셋 측정

# %%
# 판매 데이터 기본 통계량
train.describe()

# 매장 데이터 기본 정보
stores.head()

# 원유 가격 데이터 기본 정보
oil.head()
# Out:
#          date  dcoilwtico
# 0  2013-01-01         NaN
# 1  2013-01-02       93.14
# 2  2013-01-03       92.97
# 3  2013-01-04       93.12
# 4  2013-01-07       93.20

# %% [markdown]
# # 방통대 과제 해보기[링크 텍스트](https://)

# %%
# 2015년 1월부터 2024년 12월까지 문자열 배열 만들기
def get_year_months():
  year_months = []
  for year in range(2015, 2024+1):
    for month in range(1,12+1):
      year_months.append(f'{year}{month:02d}')
  return year_months

months = get_year_months();
print(f'{months}')
# Out:
# ['201501', '201502', '201503', '201504', '201505', '201506', '201507', '201508', '201509', '201510', '201511', '201512', '201601', '201602', '201603', '201604', '201605', '201606', '201607', '201608', '201609', '201610', '201611', '201612', '201701', '201702', '201703', '201704', '201705', '201706', '201707', '201708', '201709', '201710', '201711', '201712', '201801', '201802', '201803', '201804', '201805', '201806', '201807', '201808', '201809', '201810', '201811', '201812', '201901', '201902', '201903', '201904', '201905', '201906', '201907', '201908', '201909', '201910', '201911', '201912', '202001', '202002', '202003', '202004', '202005', '202006', '202007', '202008', '202009', '202010', '202011', '202012', '202101', '202102', '202103', '202104', '202105', '202106', '202107', '202108', '202109', '202110', '202111', '202112', '202201', '202202', '202203', '202204', '202205', '202206', '202207', '202208', '202209', '202210', '202211', '202212', '202301', '202302', '202303', '202304
# ...

# %%
import ssl
print(ssl.OPENSSL_VERSION)
print("TLS 1.2 지원:", ssl.HAS_TLSv1_2)
print("TLS 1.3 지원:", ssl.HAS_TLSv1_3)
# Out:
# OpenSSL 3.0.2 15 Mar 2022
# TLS 1.2 지원: True
# TLS 1.3 지원: True

# %%
import requests
import json
import pandas as pd

def get_year_months():
  year_months = []
  for year in range(2015, 2024+1):
    for month in range(1,12+1):
      year_months.append(f'{year}{month:02d}')
  return year_months

data = []

url = "http://apis.data.go.kr/1613000/ApHusEnergyUseInfoOfferServiceV2/getWntyAvrgEnergyUseAmountInfoSearchV2"
serviceKey = "0f6bbcacb363a3809c03696ba2df52ddd******"

try :
  for month in get_year_months() :
    params = {
        'serviceKey': serviceKey,
        'searchDate': month
    }
    response = requests.get(url,params = params)
    response.raise_for_status()

    # 데이터 넣기
    item = response.json()['response']['body']['item']
    item['date_str'] = month
    data.append(item)

  print('API 호출 완료')
  print(response.json())
except Exception as e:
  print(f"오류발생 {e}")

# with open("energy_data.json", "w", encoding="utf-8") as f:
    # json.dump(data, f, ensure_ascii=False, indent=2)

print("저장 완료: energy_data.json")
# Out:
# API 호출 완료
# {'response': {'body': {'item': {'heat': 515, 'waterHot': 155, 'gas': 3, 'elect': 711, 'waterCool': 241}}, 'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'}}}
# 저장 완료: energy_data.json

# %%
import pandas as pd

df = pd.DataFrame(data)

df
# Out:
#      heat  waterHot  gas  elect  waterCool date_str
# 0     532       132    5    674        176   201501
# 1     435       126    5    639        174   201502
# 2     329       123    4    532        173   201503
# 3     157       106    3    554        180   201504
# 4      51        88    2    506        184   201505
# ..    ...       ...  ...    ...        ...      ...
# 115    28        51    1   1292        258   202408
# 116    28        53    1   1081        253   202409
# 117    64        91    1    696        247   202410
# 118   210       118    2    646        243   202411
# 119   515       155    3    711        241   202412
#
# [120 rows x 6 columns]

# %%
# 2-2 연도별, 계절별 분석을 위해 날짜 컬럼을 활용하여 ‘year’와 ‘season’ 컬럼을 추가하는 전처리
# 코드를 작성하고, 변환 결과를 확인할 수 있는 출력 결과를 첨부하시오.

df['date'] = pd.to_datetime(df['date_str'],format='%Y%m')
df['year'] = df['date'].dt.year

df["season"] = df["date"].dt.month.map(
    lambda m: "봄" if 3 <= m <= 5
    else "여름" if 6 <= m <= 8
    else "가을" if 9 <= m <= 11
    else "겨울"
)

df
# Out:
#      heat  waterHot  gas  elect  waterCool date_str       date  year season
# 0     532       132    5    674        176   201501 2015-01-01  2015     겨울
# 1     435       126    5    639        174   201502 2015-02-01  2015     겨울
# 2     329       123    4    532        173   201503 2015-03-01  2015      봄
# 3     157       106    3    554        180   201504 2015-04-01  2015      봄
# 4      51        88    2    506        184   201505 2015-05-01  2015      봄
# ..    ...       ...  ...    ...        ...      ...        ...   ...    ...
# 115    28        51    1   1292        258   202408 2024-08-01  2024     여름
# 116    28        53    1   1081        253   202409 2024-09-01  2024     가을
# 117    64        91    1    696        247   202410 2024-10-01  2024     가을
# 118   210       118    2    646        243   202411 2024-11-01  2024     가을
# 119   515       155    3    711        241   202412 2024-12-01  2024     겨울
#
# [120 rows x 9 columns]

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 2s (6,180 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.font_manager as fm
for font in fm.findSystemFonts(fontpaths=None, fontext='ttf'):
    if "Gothic" in font or "Apple" in font:
        print(font)
# Out:
# /usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf
# /usr/share/fonts/truetype/nanum/NanumGothic.ttf
# /usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf
# /usr/share/fonts/truetype/nanum/NanumBarunGothicBold.ttf
# /usr/share/fonts/truetype/nanum/NanumGothicCodingBold.ttf
# /usr/share/fonts/truetype/nanum/NanumGothicBold.ttf

# %%
# 3-1
# 연도별 에너지 사용 총 금액(전기+가스+난방+급탕) 변화량을 선 그래프로 시각화하고,
# 그래프에 자신의 학번 뒤 4자리를 제목에 포함하여 저장하시오.
# (예: "연도별 에너지 사용 총액 변화 - 1234") 시각화 코드와 생성된 그래프를 첨부하시오.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.rc('font', family='NanumGothic')

df['date'] = pd.to_datetime(df['date_str'],format='%Y%m')
df['year'] = df['date'].dt.year
df['total_month'] = df[["heat", "waterHot", "gas", "elect", "waterCool"]].sum(axis = 1)

yearly = df.groupby('year')['total_month'].sum()

plt.figure(figsize=(12, 6))
plt.plot(yearly.index, yearly.values)
plt.title("연도별 열 사용량 변화 - 4515")
plt.xlabel("연도")
plt.ylabel("연도별 에너지 사용 총 금액")
plt.grid(True)
plt.show()

# %%
# 3-2
# 계절별 난방사용금액 평균을 막대 그래프로 시각화하기
# 각 막대에 구체적인 수치를 표시하고, 시각화 코드와 생성된 그래프를 첨부한다.

df
# Out:
#      heat  waterHot  gas  elect  waterCool date_str       date  year season
# 0     532       132    5    674        176   201501 2015-01-01  2015     겨울
# 1     435       126    5    639        174   201502 2015-02-01  2015     겨울
# 2     329       123    4    532        173   201503 2015-03-01  2015      봄
# 3     157       106    3    554        180   201504 2015-04-01  2015      봄
# 4      51        88    2    506        184   201505 2015-05-01  2015      봄
# ..    ...       ...  ...    ...        ...      ...        ...   ...    ...
# 115    28        51    1   1292        258   202408 2024-08-01  2024     여름
# 116    28        53    1   1081        253   202409 2024-09-01  2024     가을
# 117    64        91    1    696        247   202410 2024-10-01  2024     가을
# 118   210       118    2    646        243   202411 2024-11-01  2024     가을
# 119   515       155    3    711        241   202412 2024-12-01  2024     겨울
#
# [120 rows x 9 columns]

# %%
# 3-1
# 연도별 에너지 사용 총 금액(전기+가스+난방+급탕) 변화량을 선 그래프로 시각화하고,
# 그래프에 자신의 학번 뒤 4자리를 제목에 포함하여 저장하시오.
# (예: "연도별 에너지 사용 총액 변화 - 1234") 시각화 코드와 생성된 그래프를 첨부하시오.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
plt.rc('font', family='NanumGothic')

### 결측치 히트맵

df = pd.read_json("energy_data.json")

df['date'] = pd.to_datetime(df['date_str'],format='%Y%m')
df['year'] = df['date'].dt.year

df["season"] = df["date"].dt.month.map(
    lambda m: "봄" if 3 <= m <= 5
    else "여름" if 6 <= m <= 8
    else "가을" if 9 <= m <= 11
    else "겨울"
)

# 계절 → 숫자 매핑
season_order_map = {"봄": 1, "여름": 2, "가을": 3, "겨울": 4}

df["season_order"] = df["season"].map(season_order_map)

yearly = df.groupby('season').mean()

yearly_sorted = yearly.sort_values("season_order")

plt.figure(figsize=(12, 6))
bar = sns.barplot(x='season', y='heat', data=yearly_sorted)

# bar 객체 가져오기
for container in bar.containers:
    bar.bar_label(container, fmt="%.1f", padding=3)

plt.title("계절별 난방사용금액 평균")
plt.xlabel("계절")
plt.ylabel("사용량")
plt.xticks(rotation=90)
plt.show()

# %%
# 시각화 결과를 바탕으로 연도별 에너지 사용 총액 변화에서 나타나는 주요 트렌드를 찾아 분석한다
# 그 원인을 추론하여 500자 정도로 설명하시오

시각화 결과를 확인해보면
